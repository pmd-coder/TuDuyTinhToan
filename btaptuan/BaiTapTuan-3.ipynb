# %% [markdown]
# #### W3A1
# Nhập vào một số nguyên dương có 3 chữ số. Tìm và in ra màn hình “SỐ
# NGUYÊN” đảo ngược của n. Không dùng kiểu chuỗi. Chú ý: kiểm tra chỉ xử
# lý các số nguyên dương có đúng 3 chữ số. Các số khác không xử lý

# %%
a=int(input())
if 100<=a<=999:
    so1=a%10
    so2=(a//10)%10
    so3=(a//100)%10
    print(so1*100+so2*10+so3)
# Out:
# 321

# %% [markdown]
# #### Hoán đổi hai số không sd biến tạm thời
# Sử dụng phép toán XOR trên bit để hoán đổi giá trị của hai biến.
# Đọc và tự tìm hiểu các phép toán trên bit: AND, OR, XOR

# %% [markdown]
# #### Viêt chương trình chia một số m cho n, kết quả thu được làm tròn xuống

# %%
m,n = map(float, input().split())
print(m//n)
# Out:
# 2.0

# %% [markdown]
# #### Viêt chương trình chia một số m cho n, kết quả thu được làm tròn lên

# %%
m,n = map(float, input().split())
import math
math.ceil(m/n) #(ceil floor) (round int) //
# Out:
# 1

# %% [markdown]
# #### [Even and Odd]
# Nhập vào một số nguyên dương x, bạn hãy kiểm tra xem x là số chẵn hay lẻ.
# Nếu x là số chẵn, in ra "Even". Nếu x là số lẻ, in ra "Odd".

# %%
x=int(input())
if x%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %% [markdown]
# ### W3A7
# [Check negative numbers]
# Nhập vào hai số nguyên a, b. Nếu cả hai số a, b đều âm thì in ra "Yes", ngược lại in No

# %% [markdown]
# #### W3A8
# [Longer string]
# Nhập vào hai chuỗi a, b gồm các chữ cái thường. In ra "True" nếu chuỗi a dài hơn chuỗi b. Ngược lại in ra "False".

# %%
s1, s2 = input("Nhập hai chuỗi: ").split()
if len(a)>len(b):
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# #### W3A16
# [Rounding]
# Nhập vào một số thực: in ra kết quả làm tròn lên, tròn xuống, làm tròn tới số
# nguyên gần nhất (không được sử dụng hàm sẵn có của pyton). Các kết quả
# cách nhau một dấu cách

# %%
a=float(input())
if a>0:
    len=int(a+1)
    xuong=(int(a))
    gannhat=int(a+0.5)
elif a==0:
    len=xuong=gannhat=a
else:
    len=int(a-1)
    xuong=(int(a))
    gannhat=int(a-0.5)
print(len, xuong, gannhat)
# Out:
# 7 6 7

# %%
def doixung(n):
    goc=n
    doix=0
    while n>0:
        digit=n%10
        doix=doix*10+digit
        n//=10
    return doix
def kiemtra(n):
    if n != doixung(n):
        return True
    return False
a=int(input())
dem=0
while kiemtra(a):
    a=a+doixung(a)
    dem=dem+1
print(a, dem)
# Out:
# 121 2

# %%
def doix(a):
    doixung=int((str(a)[::-1]))
    return doixung
def check(a):
    if a!=doix(a):
        return True
    return False
n=int(input())
dem=0
while check(n):
    n=n+doix(n)
    dem=dem+1
print(n, dem)
# Out:
# 12 0
