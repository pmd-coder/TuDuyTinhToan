# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntíchvàchu vi của nó.

# %%
a, b =map(int, input().split())
print("Diện tích là", a*b)
print("Chu vi là", (a+b)*2)
# Out:
# Diện tích là 2
# Chu vi là 6

# %% [markdown]
# #### Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
import math
a=float(input())
S=math.pi*(a**2)
P=2*math.pi*a
print(f"{S:.1f} {P:.1f}")
# Out:
# 3.1 6.3

# %% [markdown]
# #### Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra mànhình.

# %%
a, b, c = map(float, input().split())
if a + b >c and b+c>a and a+c>b and min(a, b, c)>0:
   if a==b==c:
      print("tgv")
   elif a**2+b**2==c**2 or a**2+c**2==b**2 or b**2+c**2==a**2:
      print("tgv")
   elif a==b or b==c or c==a:
      print("tgc")
   else:
      print("tgt")
   p=(a+b+c)/2
   s=(p*(p-a)*(p-b)*(p-c))**0.5
   print("dien tich la", s)
else:
   print("kptg")

# %% [markdown]
# #### Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a, b = map(float, input().split())
if a==0:
    if b==0:
        print("pt vô số nghiệm")
    else:
        print("pt vô nghiệm")
else:
    print("x=",-b/a)
# Out:
# pt vô số nghiệm

# %% [markdown]
# #### Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a, b, c= map(float, input().split())
if a==0:
    if b==0:
        if c==0:
            print("pt vô số nghiệm")
        else:
            print("ptrinh vn")
    else:
          print("x=",-c/b)
else:
    delta=b**2-4*a*c
    n1=(-b+delta**(1/2))/(2*a)
    n2=(-b-delta**(1/2))/(2*a)
    if delta<0:
        print("pt vô nghiệm")
    elif delta==0:
        print("ptrinh có nghiệm duy nhất", -b/2*a)
    else:
        print(f"ptrinh co 2 nghiem pb {n1} và {n2}")
# Out:
# x= -0.0

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a, b, c, d=map(float, input().split())
print(max(a, b, c, d))
# Out:
# 7.0

# %%
numbers=list(map(float, input().split()[:4]))
i=0 
max=numbers[0]
for i in numbers:
    if i>max:
        max=i
print(max)
# Out:
# 4.0

# %% [markdown]
# #### Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a, b, c, d=map(float, input().split())
print(min(a, b, c, d))
# Out:
# 1.0

# %%
numbers=list(map(float, input().split()[:4]))
i=0 
min=numbers[0]
for i in numbers:
    if i<max:
        min=i
print(min)
# Out:
# 0.0

# %% [markdown]
# #### Bài 8: Giải hệ phương trình tuyến tính:
# ax  by  m
# cx  dy  n

# %%
a, b, m, c, d, n=map(float, input().split())
nhan=c/a
y=(nhan*m-n)/(nhan*b-d)
x=(m-b*y)/a
print(x, y)
# Out:
# -1.0 2.0

# %% [markdown]
# #### Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây

# %%
sec=int(input())
gio=sec//3600
phut=(sec-gio*3600)//60
giay=sec-gio*3600-phut*60
print(f"{gio} giờ {phut} phut {giay} giây")
# Out:
# 1 giờ 1 phut 8 giây

# %% [markdown]
# #### Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
x, y=map(float, input().split())
bk=float(input())
a, b=map(float, input().split())
if (x-a)**2+(y-b)**2==bk**2:
    print("True")
# Out:
# True

# %% [markdown]
# Bài 11: Tính x
# y (Với x, y là số thực)

# %%
import math
x=5
y=2
math.pow(5,2)
pow(5,2)
# Out:
# 25
