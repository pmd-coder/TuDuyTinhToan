# %%
a, b, c = map(float, input().split())
if a + b >c and b+c>a and a+c>b and min(a, b, c)>0:
   if a==b==c:
      print("tgv")
   elif a**2+b**2==c**2 or a**2+c**2==b**2 or b**2+c**2==a**2:
      print("tgv")
   elif a==b or b==c or c==a:
      print("tgc")
   else:
      print("tgt")
   p=(a+b+c)/2
   s=(p*(p-a)*(p-b)*(p-c))**0.5
   print("dien tich la", s)
else:
   print("kptg")
# Out:
# tgv
# dien tich la 6.0

# %%
x=[1, -4, 2,3 ]
k=x
x.append(8)
print(x)
x.sort()
print(x)
x.reverse
print(x)
x.sort(key=abs, reverse=True) #key: tinh chat vi du sap xep theo gia tri tuyet doi, reverse=True dao nguoc, reverse= False ko dao
k.sort( reverse=True)
print(k)
print(x)
f=sorted(x, key=abs, reverse=True )
print(f)
# Out:
# [1, -4, 2, 3, 8]
# [-4, 1, 2, 3, 8]
# [-4, 1, 2, 3, 8]
# [8, 3, 2, 1, -4]
# [8, 3, 2, 1, -4]
# [8, -4, 3, 2, 1]

# %%
a=-12345
dem=0
while abs(a)>1:
    dem+=1
    a=a/10
print(dem)
